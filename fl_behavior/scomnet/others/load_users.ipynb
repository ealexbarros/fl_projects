# %%
import pandas as pd
import glob

base_path = "/home/joaoneto/biometria/csv_files"

users_statistics = pd.read_csv("users_statistics.csv")
valid_users = users_statistics[(users_statistics.nrows >= 50000) & (users_statistics.nrows <= 400000)]["player_id"].unique()
print(valid_users)
tmp_data = []
for user in valid_users:
    for csv_file_path in glob.glob(f"{base_path}/{user}/*.csv"):
        tmp_data.append(pd.read_csv(csv_file_path))
data = pd.concat(tmp_data)
data.reset_index(inplace=True, drop=True)
# Out:
# ['gzx7rv' 'w8f2wrs' '0sqy7ba' 'fit126a' 'y6awfke' 'l1doqao' '148r1k5'
#  'd5deark' 'v7wrmv5' 'ne1igm6' 'v90gnf6' 'z8c5rtb' 'cfmwho3' 'xrm6gjj'
#  'vo441ru' '7stgp0r' 'hl7odjo' 'o6g2zef' 'sqhkewt' 'z3u2vz' 'lvrishm'
#  '508rk86' 'flidyt' 'xgz550j' 'b0602fr' 'd99p79w' '68n9ll' '2bv2c7c'
#  'zai3f1z' '3031jd7' '3ypgstx' 'ftk8v41' '7ksck80' 'y2opfq8' 'gt4yc1j'
#  'i6298h7' '8xjh8a' 'a49ifaj' 'hv7o35l' 'w0lcyp8' 'ta0ko40' '2o16sv1'
#  'lm8ujtt' 'zjod7wg' 'p9dg8v5' 'uui53he' 'pqunrw' '8aaazt3' 'u9itn0j'
#  'rsgubi' 'bo9mhqr' '33a3a5u' '9mxt26y' 'yq9ubrt' 'agmp5h7' '0z9xv36'
#  '9gx7uks' '8uohdv4' 'z8taipm' '3xhmhs7' 'rcuqzrh' 'omaw5mr' 'r2p4ljs'
#  'pxipu7n' 'w764hxe' '52cxxgh' 'n7ml8hx' '1krn0b7' 'sxvkh3b' 'ghtlpmi'
#  '677l8bq' '0hz8270' '06mdn3c' 'ji2hwh' 'ntmyzk2' 'bu0z5eh' 'd4bovm'
#  '56zi3vy' 'szmkl5t' '2j4qo8i' 'm5nq6la' 'tuvemg' 'k9ptsb2' 'b9dujd'
#  'im18fyp' 'r6ei6zy' '36z77qn' '60u0i9n' 'l3rcqx4' '3zd4fdk' 'aqq25vq'
#  'e8c79mk' '6jtbpdh' 'qa94pwy' 'cyr6jmc' 'fn4tvxu' 'cn1lmwf' 'wm3pahu'
#  'ioxyr9y']

# %%
# Out:
#          index         x         y         z  \
# 0            0 -0.045181 -0.087646 -0.992249
# 1            1 -0.047089 -0.084076 -0.915833
# 2            2 -0.043747 -0.093414 -0.997253
# 3            3 -0.045959 -0.085373 -0.987961
# 4            4 -0.046509 -0.086197 -0.993149
# ...        ...       ...       ...       ...
# 4432373    562 -0.031723 -0.470566 -0.856186
# 4432374    563 -0.080643 -0.574036 -0.889786
# 4432375    564 -0.075363 -0.574020 -0.826904
# 4432376    565 -0.099426 -0.569992 -0.787216
# 4432377    566 -0.072784 -0.565399 -0.791229
#
#                                            screen player_id
# 0        MemoriaGame - tournament_helexpo_stage.2   frl4fzq
# 1        MemoriaGame - tournament_helexpo_stage.2   frl4fzq
# 2        MemoriaGame - tournament_helexpo_stage.2   frl4fzq
# 3        MemoriaGame - tournament_helexpo_stage.2   frl4fzq
# 4        MemoriaGame - tournament_helexpo_stage.2   frl4fzq
# ...                                           ...       ...
# 4432373                        SpeedyGame - 2.1.2   36z77qn
# 4432374                        SpeedyGame - 2.1.2   36z77qn
# 4432375                        SpeedyGame - 2.1.2   36z77qn
# 4432376                        SpeedyGame - 2.1.2   36z77qn
# 4432377                        SpeedyGame - 2.1.2   36z77qn
#
# [4432378 rows x 6 columns]
