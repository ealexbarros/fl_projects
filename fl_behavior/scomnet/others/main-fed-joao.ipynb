# %%
import collections
import functools
import pandas as pd
import numpy as np
import random
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

from typing import Callable, Dict, List, Tuple

import tensorflow_federated as tff

import nest_asyncio
nest_asyncio.apply()

import tensorflow as tf
import keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers
import glob

from __future__ import absolute_import, division, print_function, unicode_literals
import functools

# %%
"""This cell does:
1. Creats an array of userids;
2. Sorts the array;
3. Creates a list of unique userids;
4. Sorts the list."""
def unique(list1):       
    list_set = set(list1) 
    unique_list = (list(list_set)) 
    unique_list.sort()
    return unique_list

def create_userids( df ):
    array = df.values
    y = array[:, -1]
    return unique( y )

# %%
"""This cell does:
1. It loads the data from the .csv file and converts it into a dataframe.
2. It splits the dataframe into train and test data.
3. It converts the 'user' column into a one-hot encoding, and converts it into an integer array.
4. It converts the integer array into a categorical array.
5. It returns the train and test data.
"""
def split_dataframe(df):
    train_X = df.iloc[:, :384].values
    le = LabelEncoder()
    df['user'] = le.fit_transform(df['user'])
    train_y = to_categorical(df['user']).astype(int)    
    return train_X, train_y

# %%
"""This cell does:
1. Creates a list of client data, each client data is a list of two elements, th first element is the input and the second element is the output.
2. Creates a tensorflow federated dataset from the list of client data.
"""
def create_uniform_dataset(
    X: np.ndarray, y: np.ndarray, number_of_clients: int
) -> Tuple[Dict, tff.simulation.datasets.ClientData]:
    """Function distributes the data equally such that each client holds equal amounts of each class.
    Args:
        X (np.ndarray): Input.\n
        y (np.ndarray): Output.\n
        number_of_clients (int): Number of clients.\n
    Returns:
        [Dict, tff.simulation.ClientData]: A dictionary and a tensorflow federated dataset containing the distributed dataset.
    """
    clients_data = {f"client_{i}": [[], []] for i in range(1, number_of_clients + 1)}
    for i in range(len(X)):
        clients_data[f"client_{(i%number_of_clients)+1}"][0].append(X[i])
        clients_data[f"client_{(i%number_of_clients)+1}"][1].append(y[i])

    return clients_data, create_tff_dataset(clients_data)

# %%
"""This cell does:
1. Create a dictionary of the clients;
2. Create a tensorflow federated dataset from the dictionary;
3. Return the federated dataset.
"""
def create_tff_dataset(clients_data: Dict) -> tff.simulation.datasets.ClientData:
    """Function converts dictionary to tensorflow federated dataset.
    Args:
        clients_data (Dict): Inputs.
    Returns:
        tff.simulation.ClientData: Returns federated data distribution.
    """
    client_dataset = collections.OrderedDict()

    for client in clients_data:
        data = collections.OrderedDict(
            (
                ("label", np.array(clients_data[client][1], dtype=np.int32)),
                ("datapoints", np.array(clients_data[client][0], dtype=np.float32)),
            )
        )
        client_dataset[client] = data

    return tff.simulation.datasets.TestClientData(client_dataset)

# %%
"""This cell does:
1. Shuffle the dataset;
2. Repeat the dataset for number of epochs;
3. Batch the dataset;
4. Reshape the dataset;
5. Return the dataset.
"""
def preprocess_dataset(
    epochs: int, batch_size: int, shuffle_buffer_size: int
) -> Callable[[tf.data.Dataset], tf.data.Dataset]:
    """Function returns a function for preprocessing of a dataset.
    Args:
        epochs (int): How many times to repeat a batch.\n
        batch_size (int): Batch size.\n
        shuffle_buffer_size (int): Buffer size for shuffling the dataset.\n
    Returns:
        Callable[[tf.data.Dataset], tf.data.Dataset]: A callable for preprocessing a dataset object.
    """

    def _reshape(element: collections.OrderedDict) -> tf.Tensor:

        return (tf.expand_dims(element["datapoints"], axis=-1), element["label"])
    """
    @tff.tf_computation(
        tff.SequenceType(
            collections.OrderedDict(
                label=tff.TensorType(tf.int32, shape=(30,)),
                datapoints=tff.TensorType(tf.float32, shape=(384,)),
            )
        )
    )
    """
    def preprocess(dataset: tf.data.Dataset) -> tf.data.Dataset:
        """
        Function returns shuffled dataset
        """
        return (
            dataset.shuffle(shuffle_buffer_size)
            .repeat(epochs)
            .batch(batch_size, drop_remainder=False)
            .map(_reshape, num_parallel_calls=tf.data.experimental.AUTOTUNE)
        )

    return preprocess

# %%
""" This cell does:
    1. Loads the data from the csv files;
    2. Splits the data into train, validation and test sets;
    3. Returns the train, validation and test sets.
"""
def load_data():
    # config
    BASE_PATH = "/home/joaoneto/biometria/csv_files"
    MIN_NUM_ROWS = 50000
    MAX_NUM_ROWS = 100000
    NUM_FRAMES = 250
    number_of_clients = 10

    users_statistics = pd.read_csv("/home/joaoneto/biometria/fl_behavior/scomnet/users_statistics.csv")
    valid_users = users_statistics[(users_statistics.nrows >= MIN_NUM_ROWS) & (users_statistics.nrows <= MAX_NUM_ROWS)]["player_id"].unique()

    tmp_data = []
    for user in valid_users:
        for csv_file_path in glob.glob(f"{BASE_PATH}/{user}/*.csv"):
            tmp_data.append(pd.read_csv(csv_file_path))
            
    data = pd.concat(tmp_data)
    data.reset_index(inplace=True, drop=True)

    users = data['player_id'].unique()
    
    train_set, user_list = split_data(data, users, NUM_FRAMES)
    train_set = np.array([np.array(x) for x in train_set]) 
    train_set_join = train_set.reshape(train_set.shape[0], 384)
    data_join = pd.DataFrame(train_set_join)
    data_join['user'] = user_list
    
    train_X, train_y = split_dataframe(data_join)
    train_client_data, train_data = create_uniform_dataset(train_X, train_y, number_of_clients)
    
    return train_data, len(train_X)
    
def split_data(data, users, num_frames):
    user_list = []
    train = []
    frame_size = 128
    step = 50

    for user in users:
        data_user = data[data['player_id']==user]  
        data_user = data_user.iloc[:,[0,1,2]]
        
        for w in random.sample(range(0, data_user.shape[0] - frame_size, step), num_frames):
            end = w + frame_size        
            frame = data_user.iloc[w:end,[0, 1, 2]]        
            train.append(frame)
            user_list.append(user)

    return train, user_list

# %%
"""This cell is a squential model for the task of classifying the data.
"""
def create_keras_model_seq(input_shape=(128,3), num_filters = 128, nbclasses = 30):
    model = keras.Sequential()
    model.add(keras.layers.Conv1D(filters=num_filters, kernel_size=8, padding='same', activation='relu', input_shape=input_shape))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv1D(filters=2*num_filters, kernel_size=5, padding='same', activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Conv1D(num_filters, kernel_size=3,padding='same', activation='relu'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dense(nbclasses, activation='softmax'))
    
    return model

# %%
"""This cell does:
1. Creates a federated model object;
2. Creates a server optimizer function;
3. Creates a client optimizer function;
4. Builds an iterative process that performs federated aggregation.
"""
def iterative_process_fn(
    tff_model: tff.learning.Model,
    server_optimizer_fn: Callable[[], tf.keras.optimizers.Optimizer],
    client_optimizer_fn: Callable[[], tf.keras.optimizers.Optimizer] = None
) -> tff.templates.IterativeProcess:
    """Function builds an iterative process that performs federated aggregation. The function offers federated averaging, federated stochastic gradient descent and robust federated aggregation.
    Args:
        tff_model (tff.learning.Model): Federated model object.\n
        server_optimizer_fn (Callable[[], tf.keras.optimizers.Optimizer]): Server optimizer function.\n
        aggregation_method (str, optional): Aggregation method. Defaults to "fedavg".\n
        client_optimizer_fn (Callable[[], tf.keras.optimizers.Optimizer], optional): Client optimizer function. Defaults to None.\n
        iterations (int, optional): [description]. Defaults to None.\n
        client_weighting (tff.learning.ClientWeighting, optional): Client weighting. Defaults to None.\n
        v (float, optional): L2 threshold. Defaults to None.\n
        compression (bool, optional): If the model should be compressed. Defaults to False.\n
        model_update_aggregation_factory (Callable[ [], tff.aggregators.UnweightedAggregationFactory ], optional): If the model should be trained with DP. Defaults to None.\n
    Returns:
        tff.templates.IterativeProcess: An Iterative Process.
    """

    return tff.learning.build_federated_averaging_process(
                tff_model,
                server_optimizer_fn = server_optimizer_fn,
                client_optimizer_fn = client_optimizer_fn
            )

# %%
""" This cell does:
    1. Loads the data from input file.
    2. Apply preprocessing to the data.
    3. Return the resulting dataset object. """
def get_datasets():
    
    train_dataset, n = load_data()
    
    train_preprocess = preprocess_dataset(
        epochs=10,
        batch_size=32,
        shuffle_buffer_size=100,
    )
    
    return train_dataset.preprocess(train_preprocess), n

# %%
""" This cell does:
    1. Loads the data from the csv files
    2. Splits the data into train, validation and test sets
    3. Returns the train, validation and test sets
"""
train_dataset, len_train_X = get_datasets()

# %%
# create server_optimizer_fn int this case we want to use the federated averaging
server_optimizer_fn = lambda: tf.keras.optimizers.SGD(learning_rate=0.0001)
# create client_optimizer_fn int this case we want to use the federated averaging
client_optimizer_fn = lambda: tf.keras.optimizers.SGD(learning_rate=0.0001)
""" other function
server_optimizer_fn = get_optimizer(server_optimizer_fn, server_optimizer_lr)
client_optimizer_fn = get_optimizer(client_optimizer_fn, client_optimizer_lr)
"""
# Out:
# ' other function\nserver_optimizer_fn = get_optimizer(server_optimizer_fn, server_optimizer_lr)\nclient_optimizer_fn = get_optimizer(client_optimizer_fn, client_optimizer_lr)\n'

# %%
""" This cell does:
1. Creates a keras model with the input spec given by the train_dataset.
2. Creates a tensorflow federated learning model with the keras model.
3. Creates a server optimizer and a client optimizer.
4. Creates a iterative process with the server optimizer and the client optimizer.
"""
input_spec = train_dataset.create_tf_dataset_for_client(train_dataset.client_ids[0]).element_spec

keras_model_fn = create_keras_model_seq()

keras_model_fn.summary()

get_keras_model = functools.partial(keras_model_fn)

loss_fn = lambda: tf.keras.losses.CategoricalCrossentropy()
metrics_fn = lambda: [tf.keras.metrics.CategoricalAccuracy()]


def model_fn() -> tff.learning.Model:
    """
    Function that takes a keras model and creates an tensorflow federated learning model.
    """
    return tff.learning.from_keras_model(
        keras_model=get_keras_model(),
        input_spec=input_spec(),
        loss=loss_fn(),
        metrics=metrics_fn(),
    )

iterative_process = iterative_process_fn(
    model_fn,
    server_optimizer_fn=server_optimizer_fn,
    client_optimizer_fn=client_optimizer_fn,
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 128, 128)          3200
#
#  batch_normalization_6 (Batc  (None, 128, 128)         512
#  hNormalization)
#
#  conv1d_7 (Conv1D)           (None, 128, 256)          164096
#
#  batch_normalization_7 (Batc  (None, 128, 256)         1024
#  hNormalization)
#
#  conv1d_8 (Conv1D)           (None, 128, 128)          98432
#
#  batch_normalization_8 (Batc  (None, 128, 128)         512
#  hNormalization)
#
#  global_average_pooling1d_2   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 30)                3870
#
# =================================================================
# Total params: 271,646
# Trainable params: 270,622
# Non-trainable params: 1,024
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb Cell 13' in <cell line: 30>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=19'>20</a>     """
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=20'>21</a>     Function that takes a keras model and creates an tensorflow federated learning model.
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=21'>22</a>     """
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=22'>23</a>     return tff.learning.from_keras_model(
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=23'>24</a>         keras_model=get_keras_model(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=24'>25</a>         input_spec=input_spec(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=25'>26</a>         loss=loss_fn(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=26'>27</a>         metrics=metrics_fn(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=27'>28</a>     )
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=29'>30</a> iterative_process = iterative_process_fn(
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=30'>31</a>     model_fn,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=31'>32</a>     server_optimizer_fn=server_optimizer_fn,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=32'>33</a>     client_optimizer_fn=client_optimizer_fn,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=33'>34</a> )
#
# /home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb Cell 9' in iterative_process_fn(tff_model, server_optimizer_fn, client_optimizer_fn)
#       <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=6'>7</a> def iterative_process_fn(
#       <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=7'>8</a>     tff_model: tff.learning.Model,
#       <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=8'>9</a>     server_optimizer_fn: Callable[[], tf.keras.optimizers.Optimizer],
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=9'>10</a>     client_optimizer_fn: Callable[[], tf.keras.optimizers.Optimizer] = None
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=10'>11</a> ) -> tff.templates.IterativeProcess:
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=11'>12</a>     """Function builds an iterative process that performs federated aggregation. The function offers federated averaging, federated stochastic gradient descent and robust federated aggregation.
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=12'>13</a>     Args:
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=13'>14</a>         tff_model (tff.learning.Model): Federated model object.\n
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=23'>24</a>         tff.templates.IterativeProcess: An Iterative Process.
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=24'>25</a>     """
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=26'>27</a>     return tff.learning.build_federated_averaging_process(
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=27'>28</a>                 tff_model,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=28'>29</a>                 server_optimizer_fn = server_optimizer_fn,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=29'>30</a>                 client_optimizer_fn = client_optimizer_fn
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000008vscode-remote?line=30'>31</a>             )
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py:285, in build_federated_averaging_process(model_fn, client_optimizer_fn, server_optimizer_fn, client_weighting, broadcast_process, model_update_aggregation_factory, metrics_aggregator, use_experimental_simulation_loop)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=280'>281</a> def client_fed_avg(model_fn: Callable[[], model_lib.Model]) -> ClientFedAvg:
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=281'>282</a>   return ClientFedAvg(model_fn(), client_optimizer_fn, client_weighting,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=282'>283</a>                       use_experimental_simulation_loop)
# --> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=284'>285</a> iter_proc = optimizer_utils.build_model_delta_optimizer_process(
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=285'>286</a>     model_fn,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=286'>287</a>     model_to_client_delta_fn=client_fed_avg,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=287'>288</a>     server_optimizer_fn=server_optimizer_fn,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=288'>289</a>     broadcast_process=broadcast_process,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=289'>290</a>     model_update_aggregation_factory=model_update_aggregation_factory,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=290'>291</a>     metrics_aggregator=metrics_aggregator)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=292'>293</a> server_state_type = iter_proc.state_type.member
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=294'>295</a> @computations.tf_computation(server_state_type)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/federated_averaging.py?line=295'>296</a> def get_model_weights(server_state):
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py:568, in build_model_delta_optimizer_process(model_fn, model_to_client_delta_fn, server_optimizer_fn, broadcast_process, model_update_aggregation_factory, metrics_aggregator)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=563'>564</a> py_typecheck.check_callable(model_fn)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=564'>565</a> py_typecheck.check_callable(model_to_client_delta_fn)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=566'>567</a> @computations.tf_computation
# --> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=567'>568</a> def model_and_optimizer_init_fn(
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=568'>569</a> ) -> Tuple[model_utils.ModelWeights, List[tf.Variable]]:
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=569'>570</a>   """Returns initial model weights and state of the global optimizer."""
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=570'>571</a>   model_variables = model_utils.ModelWeights.from_model(model_fn())
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py:494, in ComputationWrapper.__call__(self, tff_internal_types, *args)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=490'>491</a> else:
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=491'>492</a>   # Either we have a concrete parameter type, or this is no-arg function.
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=492'>493</a>   parameter_type = _parameter_type(parameters, parameter_types)
# --> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=493'>494</a>   wrapped_func = self._strategy(
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=494'>495</a>       fn_to_wrap, fn_name, parameter_type, unpack=None)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=496'>497</a> # Copy the __doc__ attribute with the documentation in triple-quotes from
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=497'>498</a> # the decorated function.
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=498'>499</a> wrapped_func.__doc__ = getattr(fn_to_wrap, '__doc__', None)
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py:222, in PythonTracingStrategy.__call__(self, fn_to_wrap, fn_name, parameter_type, unpack)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=219'>220</a> try:
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=220'>221</a>   args, kwargs = unpack_arguments_fn(packed_args)
# --> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=221'>222</a>   result = fn_to_wrap(*args, **kwargs)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=222'>223</a>   if result is None:
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/core/impl/wrappers/computation_wrapper.py?line=223'>224</a>     raise ComputationReturnedNoneError(fn_to_wrap)
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py:571, in build_model_delta_optimizer_process.<locals>.model_and_optimizer_init_fn()
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=566'>567</a> @computations.tf_computation
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=567'>568</a> def model_and_optimizer_init_fn(
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=568'>569</a> ) -> Tuple[model_utils.ModelWeights, List[tf.Variable]]:
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=569'>570</a>   """Returns initial model weights and state of the global optimizer."""
# --> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=570'>571</a>   model_variables = model_utils.ModelWeights.from_model(model_fn())
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=571'>572</a>   optimizer = keras_optimizer.build_or_verify_tff_optimizer(
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=572'>573</a>       server_optimizer_fn,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=573'>574</a>       model_variables.trainable,
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=574'>575</a>       disjoint_init_and_next=True)
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=575'>576</a>   trainable_tensor_specs = tf.nest.map_structure(
#     <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/tensorflow_federated/python/learning/framework/optimizer_utils.py?line=576'>577</a>       lambda v: tf.TensorSpec(v.shape, v.dtype), model_variables.trainable)
#
# /home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb Cell 13' in model_fn()
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=18'>19</a> def model_fn() -> tff.learning.Model:
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=19'>20</a>     """
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=20'>21</a>     Function that takes a keras model and creates an tensorflow federated learning model.
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=21'>22</a>     """
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=22'>23</a>     return tff.learning.from_keras_model(
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=23'>24</a>         keras_model=get_keras_model(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=24'>25</a>         input_spec=input_spec(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=25'>26</a>         loss=loss_fn(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=26'>27</a>         metrics=metrics_fn(),
#      <a href='vscode-notebook-cell://ssh-remote%2Bgercom.ddns.net/home/joaoneto/fl_projects/fl_behavior/scomnet/others/main-fed-joao.ipynb#ch0000012vscode-remote?line=27'>28</a>     )
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=66'>67</a>   raise e.with_traceback(filtered_tb) from None
#      <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=67'>68</a> finally:
#      <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/utils/traceback_utils.py?line=68'>69</a>   del filtered_tb
#
# File ~/anaconda3/envs/venv/lib/python3.9/site-packages/keras/engine/base_layer.py:3094, in Layer._split_out_first_arg(self, args, kwargs)
#    <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/engine/base_layer.py?line=3091'>3092</a>   inputs = kwargs.pop(self._call_fn_args[0])
#    <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/engine/base_layer.py?line=3092'>3093</a> else:
# -> <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/engine/base_layer.py?line=3093'>3094</a>   raise ValueError(
#    <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/engine/base_layer.py?line=3094'>3095</a>       'The first argument to `Layer.call` must always be passed.')
#    <a href='file:///home/joaoneto/anaconda3/envs/venv/lib/python3.9/site-packages/keras/engine/base_layer.py?line=3095'>3096</a> return inputs, args, kwargs
#
# ValueError: The first argument to `Layer.call` must always be passed.
